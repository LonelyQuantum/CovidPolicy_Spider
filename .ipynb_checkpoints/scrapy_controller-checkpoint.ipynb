# %%
# !scrapy crawl announcement_spider -a city=广州 -o results/json/广州.json
# Out:
# 2020-05-02 18:07:13 [scrapy.utils.log] INFO: Scrapy 2.1.0 started (bot: covid_policy_spider)
# 2020-05-02 18:07:13 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.5 (v3.7.5:5c02a39a0b, Oct 14 2019, 18:49:57) - [Clang 6.0 (clang-600.0.57)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Darwin-19.4.0-x86_64-i386-64bit
# 2020-05-02 18:07:13 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'covid_policy_spider',
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'covid_policy_spider.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['covid_policy_spider.spiders']}
# 2020-05-02 18:07:13 [scrapy.extensions.telnet] INFO: Telnet Password: 9b064d8a2f6b17ba
# 2020-05-02 18:07:13 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
# ...

# %%
type('sss') is str
# Out:
# True
